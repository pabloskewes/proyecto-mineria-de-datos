# %% [markdown]
# # Índices Educación Superior Periodo 2005-2023

# %% [markdown]
# ## Introducción
# La educación es uno de los pilares de la sociedad, y se ha visto afectada por diversas medidas e hitos como:
#
# * Movilizaciones (2006, 2011)
# * Implementación de ayudas económicas (Beca Vocación de Profesor, Gratuidad)
# * Medidas de paridad
# * Cambios en los sistemas de ingresos (PSU, PTU, PAES)
#
# Se hace interesante comprender cómo afectaron estas medidas externas a la educación superior, por ejemplo en cantidad de matrículas de primer año y vacantes en cada carrera.
# Se posee una base de datos histórica de educación superior que cuenta con registros entre 2005 y 2023.

# %% [markdown]
# ## Exploración de datos

# %% [markdown]
# Se puede observar que este dataset cuenta con 60 columnas, las cuales describen las características de cada carrera, como su nombre, institución, tipo de carrera, entre otras.
#
# ![columnas.png](attachment:columnas.png)

# %% [markdown]
# Para un posterior preprocesamiento de los datos, se observan la cantidad de registros únicos y nulos en cada una de estas columnas.
# ![nulls.png](attachment:nulls.png)

# %% [markdown]
# ### Distribuciones importantes

# %% [markdown]
# En primer lugar, se decide contabilizar el porcentaje de registros correspondientes a carreras de pregrado y postgrado, resultando en un 83.8% y 16.2% respectivamente.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Por otra parte, la distribución de estudiantes por regiones es la siguiente:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Aunque pudiese ser predecible, se evidencia una alta cantidad de estudiantes en la Región Metropolitana, seguida por Valparaíso y Biobío.

# %% [markdown]
# En cuanto a la cantidad de estudiantes por tipo de carrera, se observa que la mayoría de los estudiantes se encuentran en carreras de tipo técnicas, seguidas por profesional con licenciatura y carreras profesionales.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Agrupando las carreras por sector de conocimiento, se puede observar una gran presencia de estudiantes en carreras tecnológicas, seguidas por el área de administración y comercio. En tercer puesto, encontramos el área de salud que es casi equiparada por el área de educación.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Por el lado de las estadísticas relacionadas al ingreso a estas carreras, primero tenemos el promedio del puntaje obtenido en las pruebas de matemáticas y lenguaje.
# Cabe mencionar que los resultados registrados entre los años 2005 y 2019 corresponden a la prueba de selección universitaria PSU, con un puntaje mínimo de 150 puntos y un máximo de 850 puntos. Los siguientes 3 años corresponden a resultados de la prueba de transición universitaria PTU, mientras que el último año registrado corresponde a la nueva prueba de acceso a la educación superior PAES, cuyo rango de puntajes va desde los 100 hasta los 1.000 puntos.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# A continuación, se observa la distribución de los puntajes de matemáticas y lenguaje, donde se puede apreciar que en el caso de la PSU la mayoría de los estudiantes obtienen puntajes entre 400 y 700 puntos en ambas pruebas (recordar que la escala de cada una de las pruebas de la PSU estaba estandarizado, con una media de 500 puntos y una desviación estándar de 110).
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Preguntas de interés
#
# Preguntas a que se podrían resolver usando la minería de datos:
# 1. ¿Es posible predecir el puntaje de corte esperado para el próximo año a partir de las tendencias históricas?
# 2. ¿Existen grupos con características comunes? ¿Se pueden agrupar instituciones que tienen perfiles similares de arancel y puntaje de corte? ¿Hay alguna otra característica que pueda relacionar instituciones?
#
# Ambos puntos se podrían responder utilizando la minería de datos como herramienta. A partir del estudio inicial del dataset se cree que hay datos suficientes para responder las preguntas antes planteadas. Resulta interesante construir un predictor de puntajes de corte creado con datos reales, y no con simples estimaciones, o analizar el perfil de las instituciones de acuerdo a las características que se puedan extraer a partir de los atributos de la base de datos, ya que mediante simple análisis visual de las bases no siempre es directa la relación entre características de miles de datos disponibles.

# %% [markdown]
# ## Hallazgos

# %% [markdown]
# #### 1. Evolución de total de estudiantes año

# %% [markdown]
# Considerando las distintas medidas implementadas en torno al acceso a la educación y los diferentes contextos nacionales e internacionales, se hace interesante observar la evolución de la cantidad de estudiantes en el tiempo.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 2. Efecto en la matrícula en educación superior (universidades) del ingreso de la gratuidad al sistema de becas

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Podemos ver que hay una clara disminución de matrículas de primer año en el año 2020, ¿a qué se debe esto?

# %% [markdown]
# #### 3. Influencia beca Vocación de Profesor

# %% [markdown]
# Considerando que la BVP aplica solo a algunas carreras relacionadas a pedagogia, primero se debe filtrar el dataset para obtener solo estas carreras. Luego, se puede observar la evolución de la cantidad de estudiantes en el tiempo.
#
# ![image.png](attachment:image.png)
# ![carreras.png](attachment:carreras.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Muchas carreras tienen el nombre pedagogía, por lo que para hacer un análisis general de la influencia de la beca vocación de profesor, se agruparán las carreras que contengan la palabra pedagogía en su nombre.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Podemos ver que hay una clara aumento de matrículas de primer año en el año 2010, a un año de la implementación de la beca. Por otro lado, esta disminuye drásticamente con el tiempo.

# %% [markdown]
# - ¿es posible que esta fuga de nuevos estudiantes se deba a un incremento en las matrículas de otras carreras?
# - ¿que ha ocurrido con los puntajes de corte de las carreras de pedagogía?
# - ¿a que área pertenecen las carreras que han abierto ultimamente?
# - ¿que ha ocurrido con la distribucion de estudiantes por sexo?

# %% [markdown]
# #### 4. Influencia programas de motivación para mujeres en STEM

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Distribución de tareas**
#
# A continuación se presenta la distribución de tareas y aportes para el Hito 1. Es importante mencionar que se tuvieron reuniones de coordinación del grupo, y que todas las ideas fueron conversadas por los 5 integrantes. A partir de esto, las tareas individuales fueron:
#
# 1. Paola Silva: Apoyó en la confección de la presentación, redacción del informe y construcción de gráficos.
#
# 2. Cynthia Vega: Confección de la presentación.
#
# 3. Pablo Skewes: Confección de gráficos para el hito. Aporte en la confección del informe.
#
# 4. Isaias Venegas: Redacción de parte del informe y encargado de presentar.
#
# 5. Carla Guzmán Roa: Exploración inicial del dataset, propuesta de preguntas a resolver a grandes rasgos a partir del dataset para compartirlo con el grupo. Pequeño aporte al informe y encargada de presentar.
#
# Inicialmente se había decidido trabajar con un dataset privado correspondiente al comportamiento de los estudiantes en cursos realizados de forma híbrida. Sin embargo, ante diversos problemas que se presentaron durante la exploración del archivo proporcionado se desistió de esa opción. Aún así, creemos necesario mencionar el trabajo hecho por Pablo e Isaías en tratar de explotar los datos a partir del archivo mencionado.

# %% [markdown]
# ## Anexo

# %%
from typing import List
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
DATA_DIR = Path('../data').resolve()
assert DATA_DIR.exists()

# %%
df = pd.read_excel('../data/base_indices_2005-2023.xlsx', sheet_name='BaseINDICES_2005_2023')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218773 entries, 0 to 218772
# Data columns (total 60 columns):
#  #   Column                                              Non-Null Count   Dtype
# ---  ------                                              --------------   -----
#  0   Año                                                 218773 non-null  int64
#  1   Cód. Institución                                    218773 non-null  int64
#  2   Nombre Institución                                  218773 non-null  object
#  3   Tipo Institución                                    218773 non-null  object
#  4   Clasificación1                                      218773 non-null  object
#  5   Clasificación2                                      218773 non-null  object
#  6   Clasificación3                                      218773 non-null  object
#  7   Clasificación4                                      218773 non-null  object
#  8   Clasificación5                                      218773 non-null  object
#  9   Clasificación6                                      218773 non-null  object
#  10  Nombre de la Sede                                   218773 non-null  object
#  11  Comuna donde se imparte la carrera o programa       218773 non-null  object
#  12  Nombre Region                                       218773 non-null  object
#  13  Orden Geográfico de la Región (Norte aSur)          218773 non-null  int64
#  14  Cód. Carrera                                        218773 non-null  int64
#  15  Carrera Genérica                                    218773 non-null  object
#  16  Nombre Programa                                     218773 non-null  object
#  17  Mención o Especialidad                              30680 non-null   object
#  18  Horario                                             218773 non-null  object
#  19  Tipo Programa                                       218773 non-null  object
#  20  Area Conocimiento                                   218773 non-null  object
#  21  idgenerocarrera                                     218773 non-null  int64
#  22  Tipo Carrera                                        218773 non-null  object
#  23  IngresoDirecto                                      218773 non-null  object
#  24  Año Inicio Actividades                              218773 non-null  int64
#  25  Nombre del Campus                                   103207 non-null  object
#  26  Duración (en semestres)                             218047 non-null  float64
#  27  Cód. Campus                                         103525 non-null  float64
#  28  Cód. Sede                                           218773 non-null  int64
#  29  Título                                              189124 non-null  object
#  30  Grado Académico                                     81864 non-null   object
#  31  Máximo Puntaje (promedio matemáticas y lenguaje)    40018 non-null   float64
#  32  Promedio Puntaje (promedio matemáticas y lenguaje)  39726 non-null   float64
#  33  Mínimo Puntaje (promedio matemáticas y lenguaje)    39568 non-null   float64
#  34  Puntaje de corte (primer seleccionado)              34029 non-null   float64
#  35  Puntaje de corte (promedio de la carrera)           33932 non-null   float64
#  36  Puntaje de corte (último seleccionado)              36064 non-null   float64
#  37  Máximo Puntaje NEM                                  19956 non-null   float64
#  38  Promedio Puntaje NEM                                20141 non-null   float64
#  39  Mínimo Puntaje NEM                                  19943 non-null   float64
#  40  Máximo Puntaje Ranking                              18957 non-null   float64
#  41  Promedio Puntaje Ranking                            19100 non-null   float64
#  42  Mínimo Puntaje Ranking                              18944 non-null   float64
#  43  Nº Alumnos Ingreso Via PSU o PDT                    41330 non-null   float64
#  44  Nº Alumnos Ingreso Otra Via                         69896 non-null   float64
#  45  Valor de matrícula                                  168361 non-null  float64
#  46  Valor de arancel                                    163249 non-null  float64
#  47  Valor del Título                                    182002 non-null  float64
#  48  Tipo Moneda                                         218773 non-null  object
#  49  Vacantes                                            160361 non-null  float64
#  50  Matrícula primer año hombres                        197991 non-null  float64
#  51  Matrícula primer año mujeres                        197741 non-null  float64
#  52  Matrícula primer año extranjeros                    157630 non-null  float64
#  53  Matrícula Primer Año                                218773 non-null  int64
#  54  Matrícula total hombres                             215556 non-null  float64
#  55  Matrícula total mujeres                             215164 non-null  float64
#  56  Matrícula total extranjeros                         166431 non-null  float64
#  57  Matrícula Total                                     218773 non-null  int64
#  58  Códgo SIES                                          143336 non-null  object
#  59  Pregrado/Posgrado                                   218773 non-null  object
# dtypes: float64(26), int64(9), object(25)
# memory usage: 100.1+ MB

# %%
df.describe()
# Out:
#                  Año  Cód. Institución  \
# count  218773.000000     218773.000000
# mean     2014.907150       1671.081198
# std         5.207307        758.769099
# min      2005.000000       1001.000000
# 25%      2011.000000       1028.000000
# 50%      2015.000000       1054.000000
# 75%      2019.000000       2029.000000
# max      2023.000000       4063.000000
#
#        Orden Geográfico de la Región (Norte aSur)   Cód. Carrera  \
# count                               218773.000000  218773.000000
# mean                                     7.793297   18328.475397
# std                                      2.942522   13057.761699
# min                                      1.000000    1000.000000
# 25%                                      7.000000    7414.000000
# 50%                                      7.000000   15808.000000
# 75%                                     10.000000   28045.000000
# max                                     16.000000   51341.000000
#
#        idgenerocarrera  Año Inicio Actividades  Duración (en semestres)  \
# count     2.187730e+05           218773.000000            218047.000000
# mean      8.562085e+05             2005.765213                 6.490738
# std       3.456971e+05               12.436666                 2.599009
# min       1.060100e+04             1833.000000                 1.000000
# 25%       1.004002e+06             2003.000000                 4.000000
# 50%       1.008010e+06             2008.000000                 6.000000
# 75%       1.009010e+06             2013.000000                 8.000000
# max       2.030005e+06             2023.000000                15.000000
#
#         Cód. Campus     Cód. Sede  \
# count  1.035250e+05  2.187730e+05
# mean   1.431034e+09  1.671086e+06
# std    6.394409e+08  7.587712e+05
# min    0.000000e+00  1.001001e+06
# 25%    1.020001e+09  1.028001e+06
# 50%    1.040001e+09  1.054001e+06
# 75%    2.012004e+09  2.029007e+06
# max    4.045001e+09  4.063001e+06
#
#        Máximo Puntaje (promedio matemáticas y lenguaje)  ...  \
# count                                      40018.000000  ...
# mean                                         652.792069  ...
# std                                           87.250824  ...
# min                                          266.000000  ...
# 25%                                          599.000000  ...
# 50%                                          652.000000  ...
# 75%                                          706.000000  ...
# max                                         1000.000000  ...
#
#        Valor del Título      Vacantes  Matrícula primer año hombres  \
# count      1.820020e+05  1.603610e+05                 197991.000000
# mean       1.614738e+05  4.473227e+02                     15.603937
# std        2.391593e+05  6.596259e+04                     25.240674
# min        0.000000e+00  1.000000e+00                      0.000000
# 25%        1.700000e+03  2.200000e+01                      1.000000
# 50%        8.600000e+04  3.000000e+01                      8.000000
# 75%        2.100000e+05  5.000000e+01                     20.000000
# max        7.198000e+06  1.078400e+07                    860.000000
#
#        Matrícula primer año mujeres  Matrícula primer año extranjeros  \
# count                 197741.000000                     157630.000000
# mean                      16.475824                          0.584223
# std                       26.284474                          2.254553
# min                        0.000000                          0.000000
# 25%                        1.000000                          0.000000
# 50%                        8.000000                          0.000000
# 75%                       22.000000                          0.000000
# max                     1203.000000                        252.000000
#
#        Matrícula Primer Año  Matrícula total hombres  Matrícula total mujeres  \
# count         218773.000000            215556.000000            215164.000000
# mean              29.013567                45.751842                49.029275
# std               41.611269                86.541233                86.335418
# min                0.000000                 0.000000                 0.000000
# 25%                1.000000                 6.000000                 5.000000
# 50%               19.000000                19.000000                18.000000
# 75%               40.000000                52.000000                56.000000
# max             1954.000000              4221.000000              2745.000000
#
#        Matrícula total extranjeros  Matrícula Total
# count                166431.000000    218773.000000
# mean                      1.548221        93.299534
# std                       6.703305       148.857924
# min                       0.000000         1.000000
# 25%                       0.000000        17.000000
# 50%                       0.000000        46.000000
# 75%                       1.000000       111.000000
# max                     967.000000      6048.000000
#
# [8 rows x 35 columns]

# %%
for col in df.columns:
    print(f"Columna: {col} - Valores únicos: {df[col].nunique()} - Porcentaje de nulos: {df[col].isnull().sum() / len(df) * 100:.2f}%")
# Out:
# Columna: Año - Valores únicos: 19 - Porcentaje de nulos: 0.00%
# Columna: Cód. Institución - Valores únicos: 247 - Porcentaje de nulos: 0.00%
# Columna: Nombre Institución - Valores únicos: 247 - Porcentaje de nulos: 0.00%
# Columna: Tipo Institución - Valores únicos: 4 - Porcentaje de nulos: 0.00%
# Columna: Clasificación1 - Valores únicos: 6 - Porcentaje de nulos: 0.00%
# Columna: Clasificación2 - Valores únicos: 8 - Porcentaje de nulos: 0.00%
# Columna: Clasificación3 - Valores únicos: 2 - Porcentaje de nulos: 0.00%
# Columna: Clasificación4 - Valores únicos: 6 - Porcentaje de nulos: 0.00%
# Columna: Clasificación5 - Valores únicos: 2 - Porcentaje de nulos: 0.00%
# Columna: Clasificación6 - Valores únicos: 4 - Porcentaje de nulos: 0.00%
# Columna: Nombre de la Sede - Valores únicos: 117 - Porcentaje de nulos: 0.00%
# Columna: Comuna donde se imparte la carrera o programa - Valores únicos: 127 - Porcentaje de nulos: 0.00%
# Columna: Nombre Region - Valores únicos: 16 - Porcentaje de nulos: 0.00%
# Columna: Orden Geográfico de la Región (Norte aSur) - Valores únicos: 16 - Porcentaje de nulos: 0.00%
# Columna: Cód. Carrera - Valores únicos: 33071 - Porcentaje de nulos: 0.00%
# Columna: Carrera Genérica - Valores únicos: 294 - Porcentaje de nulos: 0.00%
# Columna: Nombre Programa - Valores únicos: 7935 - Porcentaje de nulos: 0.00%
# Columna: Mención o Especialidad - Valores únicos: 1507 - Porcentaje de nulos: 85.98%
# Columna: Horario - Valores únicos: 3 - Porcentaje de nulos: 0.00%
# Columna: Tipo Programa - Valores únicos: 2 - Porcentaje de nulos: 0.00%
# Columna: Area Conocimiento - Valores únicos: 11 - Porcentaje de nulos: 0.00%
# Columna: idgenerocarrera - Valores únicos: 325 - Porcentaje de nulos: 0.00%
# Columna: Tipo Carrera - Valores únicos: 12 - Porcentaje de nulos: 0.00%
# Columna: IngresoDirecto - Valores únicos: 2 - Porcentaje de nulos: 0.00%
# Columna: Año Inicio Actividades - Valores únicos: 107 - Porcentaje de nulos: 0.00%
# Columna: Nombre del Campus - Valores únicos: 282 - Porcentaje de nulos: 52.82%
# Columna: Duración (en semestres) - Valores únicos: 15 - Porcentaje de nulos: 0.33%
# Columna: Cód. Campus - Valores únicos: 425 - Porcentaje de nulos: 52.68%
# Columna: Cód. Sede - Valores únicos: 758 - Porcentaje de nulos: 0.00%
# Columna: Título - Valores únicos: 5749 - Porcentaje de nulos: 13.55%
# Columna: Grado Académico - Valores únicos: 3136 - Porcentaje de nulos: 62.58%
# Columna: Máximo Puntaje (promedio matemáticas y lenguaje) - Valores únicos: 591 - Porcentaje de nulos: 81.71%
# Columna: Promedio Puntaje (promedio matemáticas y lenguaje) - Valores únicos: 532 - Porcentaje de nulos: 81.84%
# Columna: Mínimo Puntaje (promedio matemáticas y lenguaje) - Valores únicos: 572 - Porcentaje de nulos: 81.91%
# Columna: Puntaje de corte (primer seleccionado) - Valores únicos: 626 - Porcentaje de nulos: 84.45%
# Columna: Puntaje de corte (promedio de la carrera) - Valores únicos: 534 - Porcentaje de nulos: 84.49%
# Columna: Puntaje de corte (último seleccionado) - Valores únicos: 619 - Porcentaje de nulos: 83.52%
# Columna: Máximo Puntaje NEM - Valores únicos: 454 - Porcentaje de nulos: 90.88%
# Columna: Promedio Puntaje NEM - Valores únicos: 545 - Porcentaje de nulos: 90.79%
# Columna: Mínimo Puntaje NEM - Valores únicos: 507 - Porcentaje de nulos: 90.88%
# Columna: Máximo Puntaje Ranking - Valores únicos: 522 - Porcentaje de nulos: 91.33%
# Columna: Promedio Puntaje Ranking - Valores únicos: 566 - Porcentaje de nulos: 91.27%
# Columna: Mínimo Puntaje Ranking - Valores únicos: 580 - Porcentaje de nulos: 91.34%
# Columna: Nº Alumnos Ingreso Via PSU o PDT - Valores únicos: 442 - Porcentaje de nulos: 81.11%
# Columna: Nº Alumnos Ingreso Otra Via - Valores únicos: 429 - Porcentaje de nulos: 68.05%
# Columna: Valor de matrícula - Valores únicos: 3226 - Porcentaje de nulos: 23.04%
# Columna: Valor de arancel - Valores únicos: 19439 - Porcentaje de nulos: 25.38%
# Columna: Valor del Título - Valores únicos: 4453 - Porcentaje de nulos: 16.81%
# Columna: Tipo Moneda - Valores únicos: 5 - Porcentaje de nulos: 0.00%
# Columna: Vacantes - Valores únicos: 445 - Porcentaje de nulos: 26.70%
# Columna: Matrícula primer año hombres - Valores únicos: 407 - Porcentaje de nulos: 9.50%
# Columna: Matrícula primer año mujeres - Valores únicos: 382 - Porcentaje de nulos: 9.61%
# Columna: Matrícula primer año extranjeros - Valores únicos: 75 - Porcentaje de nulos: 27.95%
# Columna: Matrícula Primer Año - Valores únicos: 578 - Porcentaje de nulos: 0.00%
# Columna: Matrícula total hombres - Valores únicos: 972 - Porcentaje de nulos: 1.47%
# Columna: Matrícula total mujeres - Valores únicos: 973 - Porcentaje de nulos: 1.65%
# Columna: Matrícula total extranjeros - Valores únicos: 141 - Porcentaje de nulos: 23.93%
# Columna: Matrícula Total - Valores únicos: 1459 - Porcentaje de nulos: 0.00%
# Columna: Códgo SIES - Valores únicos: 15768 - Porcentaje de nulos: 34.48%
# Columna: Pregrado/Posgrado - Valores únicos: 2 - Porcentaje de nulos: 0.00%

# %%
# Cast año a datetime
df['Año'] = pd.to_datetime(df['Año'], format='%Y')

# %%
df['Pregrado/Posgrado'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(6, 6))
plt.title('Pregrado/Posgrado')
# Out:
# Text(0.5, 1.0, 'Pregrado/Posgrado')

# %%
df['Nombre Region'].value_counts().plot(kind='barh')
plt.ylabel('Región')
plt.xlabel('Cantidad de estudiantes')
plt.title('Cantidad de estudiantes por región')

# %%
df['Tipo Carrera'].value_counts().plot(kind='barh')
plt.ylabel('Tipo de carrera')
plt.xlabel('Cantidad de estudiantes')
plt.title('Cantidad de estudiantes por tipo de carrera')

# %%
df['Area Conocimiento'].value_counts().plot(kind='barh')
plt.ylabel('Área de conocimiento')
plt.xlabel('Cantidad de estudiantes')
plt.title('Cantidad de estudiantes por área de conocimiento')

# %%
df.groupby("Año")['Promedio Puntaje (promedio matemáticas y lenguaje)'].max()
# Out:
# Año
# 2005-01-01    791.0
# 2006-01-01    802.0
# 2007-01-01    791.0
# 2008-01-01    802.0
# 2009-01-01    799.0
# 2010-01-01    802.0
# 2011-01-01    805.0
# 2012-01-01    817.0
# 2013-01-01    784.0
# 2014-01-01    779.0
# 2015-01-01    789.0
# 2016-01-01    781.0
# 2017-01-01    787.0
# 2018-01-01    796.0
# 2019-01-01    786.0
# 2020-01-01    784.0
# 2021-01-01    784.0
# 2022-01-01    786.0
# 2023-01-01    961.0
# Name: Promedio Puntaje (promedio matemáticas y lenguaje), dtype: float64

# %%
# Datos PSU y PTU
datos_puntaje_PSU_PTU=df[df['Año'].dt.year<2023]['Promedio Puntaje (promedio matemáticas y lenguaje)'].value_counts().sort_index().plot()
plt.xlabel("Promedio puntaje")
plt.ylabel("Cantidad de estudiantes")
plt.title("Distribución de promedio de puntaje para la PSU-PTU de matemáticas y lenguaje")
plt.show()

# Datos PAES
datos_puntaje_PAES=df[(df['Año'].dt.year>=2023)]['Promedio Puntaje (promedio matemáticas y lenguaje)'].value_counts().sort_index().plot()
plt.xlabel("Promedio puntaje")
plt.ylabel("Cantidad de estudiantes")
plt.title("Distribución de promedio de puntaje para la PAES de matemáticas y lenguaje")

plt.show()

# %%
estudiantes_por_año = df.value_counts('Año')
plt.xlabel('Año')
plt.ylabel('Cantidad de estudiantes')
plt.title('Cantidad de estudiantes por año')
estudiantes_por_año.plot()
# Out:
# <Axes: title={'center': 'Cantidad de estudiantes por año'}, xlabel='Año', ylabel='Cantidad de estudiantes'>

# %%
def calcular_matriculas_por_año(
    df: pd.DataFrame, columna_matricula: List[str] 
) -> pd.Series:
    """Calcula la cantidad de matriculas por año."""
    return df.groupby("Año")[columna_matricula].sum()

# %%
total_matriculas_por_año = calcular_matriculas_por_año(df, "Matrícula Primer Año")
hombres_por_año = calcular_matriculas_por_año(df, "Matrícula primer año hombres")
mujeres_por_año = calcular_matriculas_por_año(df, "Matrícula primer año mujeres")

total_matriculas_por_año.plot(label="Total")
hombres_por_año.plot(label="Hombres")
mujeres_por_año.plot(label="Mujeres")

plt.vlines(
    x="2019-01-01",
    ymin=0,
    ymax=total_matriculas_por_año.max() + 15000,
    color="red",
    linestyle="--",
    label="Año pre-pandemia y estallido social",
)
plt.vlines(
    x="2016-01-01",
    ymin=0,
    ymax=total_matriculas_por_año.max() + 15000,
    color="green",
    linestyle="--",
    label="Implementación gratuidad",
)
plt.xlabel("Año")
plt.ylabel("Número de matrículas")
plt.title("Matrículas primer año")
plt.legend()

# %%
vc = df['Carrera Genérica'].value_counts()
max_threshold = 5000

values = [len(vc[vc > t]) for t in range(max_threshold)]  
pd.Series(values, index=range(max_threshold)).plot()

plt.ylabel('Cantidad de carreras')
plt.xlabel('Threshold')
plt.title('Cantidad de carreras que aparecen en el dataset más de Threshold veces')
# Out:
# Text(0.5, 1.0, 'Cantidad de carreras que aparecen en el dataset más de Threshold veces')

# %%
threshold = 1000
carreras = vc[vc > threshold].index
carreras = df[df['Carrera Genérica'].isin(carreras)]
carreras['Carrera Genérica'].value_counts()
# Out:
# Carrera Genérica
# Posgrado                                                                26753
# Técnico en Administración de Empresas                                    7408
# Técnico en Enfermería y Similares                                        5670
# Diplomado                                                                5559
# Ingeniería en Administración, Administración de Empresas y similares     5536
# Ingeniería en Computación e Informática y similares                      4657
# Trabajo Social, Servicio Social, Planificación Social y similares        4575
# Técnico en Prevención de Riesgos                                         4438
# Ingeniería en Prevención de Riesgos                                      4195
# Contabilidad, Auditoría y similares                                      4150
# Técnico en Educación Parvularia                                          3563
# Ingeniería Comercial                                                     3269
# Postítulo                                                                3128
# Técnico en Construcción                                                  2906
# Técnico en Contabilidad, Auditoría y similares                           2821
# Técnico en Electricidad, Electrónica y similares                         2770
# Pedagogía Básica y menciones                                             2655
# Derecho                                                                  2613
# Psicología                                                               2602
# Psicopedagogía                                                           2514
# Educación Parvularia                                                     2483
# Técnico en Análisis de Sistemas Informáticos                             2206
# Técnico en Trabajo Social y similares                                    2146
# Ingeniería Civil Industrial                                              2126
# Técnico en Mecánica Automotriz                                           2059
# Técnico en Mecánica Industrial, mantención y similares                   2032
# Enfermería                                                               1990
# Técnico en Gastronomía, Cocina y similares                               1953
# Construcción Civil                                                       1932
# Técnico Asistente Jurídico y similares                                   1863
# Técnico en Turismo, Hotelería y similares                                1862
# Técnico en Deportes, Preparación Física, Recreación y similares          1803
# Técnico en Educación Especial y/o Diferencial y similares                1797
# Kinesiología                                                             1746
# Técnico en Administración de Recursos Humanos                            1722
# Ingeniería en Mecánica Automotriz                                        1682
# Técnico en Administración de Redes Computacionales                       1665
# Ingeniería Ejecución Industrial y similares                              1644
# Ingeniería en Finanzas y similares                                       1637
# Pedagogía en Inglés y similares                                          1608
# Ingeniería en Construcción y similares                                   1536
# Técnico en Odontología, Asistente Dental y similares                     1529
# Técnico en Logística y similares                                         1513
# Técnico Programador Computacional                                        1483
# Pedagogía en Educación Física y similares                                1464
# Educación Diferencial                                                    1449
# Técnico Agropecuario y similares                                         1368
# Nutrición y Dietética                                                    1327
# Diseño Gráfico, Diseño Web y similares                                   1302
# Técnico en Minas y similares                                             1248
# Administración pública y similares                                       1145
# Técnico en Comercio Exterior                                             1142
# Técnico en Computación e Informática                                     1120
# Técnico en Secretariado, Asistente ejecutivo y similares                 1093
# Fonoaudiología                                                           1063
# Ingeniería Eléctrica  y similares                                        1062
# Ingeniería Civil en Computación y/o Informática                          1030
# Name: count, dtype: int64

# %%
contains_pedagogia = (
    df["Carrera Genérica"]
    .str.lower()
    .str.normalize("NFKD")
    .str.encode("ascii", errors="ignore")
    .str.decode("utf-8")
    .str.contains("pedagogia")
)
pedagogias = df.loc[contains_pedagogia, "Carrera Genérica"].value_counts()
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color="white",
    colormap="rainbow",
    prefer_horizontal=0.5,
    contour_width=2,
    contour_color="steelblue",
    random_state=42,
)
wordcloud.generate_from_frequencies(pedagogias)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")

plt.show()

# %%
df.loc[contains_pedagogia, "Carrera Genérica"] = "Pedagogía"

# %%
df["Carrera Genérica"].value_counts().head()
# Out:
# Carrera Genérica
# Posgrado                                 26753
# Pedagogía                                12793
# Técnico en Administración de Empresas     7408
# Técnico en Enfermería y Similares         5670
# Diplomado                                 5559
# Name: count, dtype: int64

# %%
ano_beca = "2009-01-01"
total_matriculas_por_año_ped = calcular_matriculas_por_año(
    df[df["Carrera Genérica"] == "Pedagogía"], "Matrícula Primer Año"
)

total_matriculas_por_año_ped.plot(label="Matrículas primer año en pedagogía")

plt.vlines(
    x="2019-01-01",
    ymin=total_matriculas_por_año_ped.min(),
    ymax=total_matriculas_por_año_ped.max(),
    color="red",
    linestyle="--",
    label="Año pre-pandemia y estallido social",
)
plt.vlines(
    x=ano_beca,
    ymin=total_matriculas_por_año_ped.min(),
    ymax=total_matriculas_por_año_ped.max(),
    color="green",
    linestyle="--",
    label="Implementación Beca Vocación de Profesor",
)
plt.title("Matrículas primer año en pedagogía")
plt.ylabel("Matrículas")
plt.xlabel("Año")
plt.legend()

# %%
matriculas_stem = calcular_matriculas_por_año(
    df[df["Area Conocimiento"] == "Tecnología"],
    ["Matrícula primer año mujeres", "Matrícula primer año hombres"],
).copy()
matriculas_stem.index = matriculas_stem.index.year
ax = matriculas_stem.plot(kind="bar", stacked=True)

plt.xlabel("Año")
plt.ylabel("Matrículas")
plt.title("Matrículas primer año en STEM")
plt.legend(["Mujeres", "Hombres"])  # Agrega leyenda para las categorías
plt.show()
